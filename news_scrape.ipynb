# %%
import requests
import json

# api key = ed275577605e41f087491cf3545b139d

# %%
#pip install newsapi-python
from newsapi import NewsApiClient

# %%
newsapi = NewsApiClient(api_key='ed275577605e41f087491cf3545b139d')

# %%
top_headlines = newsapi.get_top_headlines(q='Apple',
                                          sources='cbc-news',
                                          domains='cbc.ca/news'
                                        #   country='ca',
                                          language='en')

# %%
url = ('https://newsapi.org/v2/top-headlines?'
       'country=ca&'
       'apiKey=ed275577605e41f087491cf3545b139d')
response = requests.get(url)
print(response.json())
# Out:
# {'status': 'ok', 'totalResults': 38, 'articles': [{'source': {'id': 'google-news', 'name': 'Google News'}, 'author': 'Ottawa Valley News', 'title': 'Q&A: Health unit answers questions about Group A strep - Ottawa Valley News', 'description': None, 'url': 'https://news.google.com/rss/articles/CBMiogFodHRwczovL3d3dy5pbnNpZGVvdHRhd2F2YWxsZXkuY29tL25ld3MvcS1hLXdpdGgtZ3JvdXAtYS1zdHJlcC1pbmZlY3Rpb25zLW9uLXRoZS1yaXNlLWluLXRoZS1vdHRhd2EtdmFsbGV5LWhlcmVzL2FydGljbGVfYjc0OTY3NGItYTU2Yy01MGYyLWJlMTktMjc0NWI1NDZlNTY2Lmh0bWzSAQA?oc=5', 'urlToImage': None, 'publishedAt': '2024-02-03T19:55:00Z', 'content': None}, {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': 'Reuters', 'title': 'Senegalese President Sall postpones presidential vote - Reuters', 'description': None, 'url': 'https://news.google.com/rss/articles/CBMibmh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3dvcmxkL2FmcmljYS9zb21lLXNlbmVnYWxlc2Utb3Bwb3NpdGlvbi1yZWplY3QtYmlkLWRlbGF5LXByZXNpZGVudGlhbC12b3RlLTIwMjQtMDItMDMv0gEA?oc=5', 'urlToIma
# ...

# %%
response.json()
# Out:
# {'status': 'ok',
#  'totalResults': 38,
#  'articles': [{'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': 'Ottawa Valley News',
#    'title': 'Q&A: Health unit answers questions about Group A strep - Ottawa Valley News',
#    'description': None,
#    'url': 'https://news.google.com/rss/articles/CBMiogFodHRwczovL3d3dy5pbnNpZGVvdHRhd2F2YWxsZXkuY29tL25ld3MvcS1hLXdpdGgtZ3JvdXAtYS1zdHJlcC1pbmZlY3Rpb25zLW9uLXRoZS1yaXNlLWluLXRoZS1vdHRhd2EtdmFsbGV5LWhlcmVzL2FydGljbGVfYjc0OTY3NGItYTU2Yy01MGYyLWJlMTktMjc0NWI1NDZlNTY2Lmh0bWzSAQA?oc=5',
#    'urlToImage': None,
#    'publishedAt': '2024-02-03T19:55:00Z',
#    'content': None},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': 'Reuters',
#    'title': 'Senegalese President Sall postpones presidential vote - Reuters',
#    'description': None,
# ...

# %%
everything = newsapi.get_everything(q='climate',
                                sources='cbc-news',
                                domains='cbc.ca/news'
                                #   country='ca',
                                #language='en')
                                )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 everything = newsapi.everything(q='climate',
#       2                                 sources='cbc-news',
#       3                                 domains='cbc.ca/news'
#       4                                 #   country='ca',
#       5                                 #language='en')
#       6                                 )
#
# AttributeError: 'NewsApiClient' object has no attribute 'everything'

# %%
everything

# %%
sources = newsapi.get_sources()
sources
# Out:
# {'status': 'ok',
#  'sources': [{'id': 'abc-news',
#    'name': 'ABC News',
#    'description': 'Your trusted source for breaking news, analysis, exclusive interviews, headlines, and videos at ABCNews.com.',
#    'url': 'https://abcnews.go.com',
#    'category': 'general',
#    'language': 'en',
#    'country': 'us'},
#   {'id': 'abc-news-au',
#    'name': 'ABC News (AU)',
#    'description': "Australia's most trusted source of local, national and world news. Comprehensive, independent, in-depth analysis, the latest business, sport, weather and more.",
#    'url': 'https://www.abc.net.au/news',
#    'category': 'general',
#    'language': 'en',
#    'country': 'au'},
#   {'id': 'aftenposten',
#    'name': 'Aftenposten',
#    'description': 'Norges ledende nettavis med alltid oppdaterte nyheter innenfor innenriks, utenriks, sport og kultur.',
#    'url': 'https://www.aftenposten.no',
#    'category': 'general',
#    'language': 'no',
#    'country': 'no'},
# ...

# %%
top_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 4,
#  'articles': [{'source': {'id': None, 'name': 'Hollywood Reporter'},
#    'author': 'Pamela McClintock',
#    'title': 'Box Office: Matthew Vaughn and Apple’s Big-Budget ‘Argylle’ Bombing With $16.5M U.S. Debut - Hollywood Reporter',
#    'description': 'Audiences slapped the $200 million movie with a C+ CinemaScore, but it will still top the North American box office, thanks to little competition.',
#    'url': 'http://www.hollywoodreporter.com/movies/movie-news/argylle-box-office-bombs-1235814232/',
#    'urlToImage': 'https://www.hollywoodreporter.com/wp-content/uploads/2024/02/5776_D033_00044R_CROP-H-2024.jpg?w=1024',
#    'publishedAt': '2024-02-03T17:12:13Z',
#    'content': 'Spurned by many critics and consumers alike, Matthew Vaughn‘s pricey spy-comedy Argylle is bombing at the North American box office in the biggest miss to date for Apple’s theatrical ambitions. \r\nThe… [+2689 chars]'},
# ...

# %%
# url = ('https://newsapi.org/v2/everthing?q=bitcoin&apiKey=ed275577605e41f087491cf3545b139d')
#        # 'country=cn'
#        # 'from=2024-01-04&'
#        # 'sortBy=popularity&'
#        #'apiKey=ed275577605e41f087491cf3545b139d')

# r = requests.get(url)

# %%
json.loads(r.read())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 json.loads(r.read())
#
# AttributeError: 'Response' object has no attribute 'read'

# %%
print(r)
# Out:
# <Response [404]>
