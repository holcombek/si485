# %%
import pandas as pd

# %%
! pip install newsapi-python

# %%
from newsapi import NewsApiClient

# %%
# Init
newsapi = NewsApiClient(api_key='9873406104694f91a2f0b080627decd5')

# %%
# /v2/top-headlines
# top_headlines = newsapi.get_everything(q='Wildfire', language='en', sources='cbc-news',)

# %%
# # cbc "climate" pull 
# all_articles_climate = newsapi.get_everything(q='climate',
#                                       sources='cbc-news' ,
#                                      domains='cbc.ca/news',
#                                       #from_param='2023-12-01',
#                                       #to='2023-12-12',
#                                       #language='en',
#                                       sort_by='relevancy')
#                                      # page=2)

# %%
# all_articles_climate

# %%
# cbc_climate = pd.DataFrame()

# %%
# cbc_climate['source_name'] = [article['source']['name'] for article in all_articles_climate['articles']]
# cbc_climate['source_id'] = [article['source']['id'] for article in all_articles_climate['articles']]
# cbc_climate['publish_date'] = [article['publishedAt'] for article in all_articles_climate['articles']]
# cbc_climate['title'] = [article['title'] for article in all_articles_climate['articles']]
# cbc_climate['text'] = [article['content'] for article in all_articles_climate['articles']]
# cbc_climate['url'] = [article['url'] for article in all_articles_climate['articles']]

# %%
source_l = ['the-globe-and-mail','cbc-news','google-news-ca', 'financial-post','nationalpost.com','ctvnews.ca','calgaryherald.com','calgaryherald.com','globalnews.ca']
q_l = ['climate', 'fire', 'wildfire', 'oil', 'temperature']

# %%
national_post_res = newsapi.get_everything(q='climate',
                                      # sources='cbc-news' ,
                                     domains='nationalpost.com',
                                      #from_param='2023-12-01',
                                      #to='2023-12-12',
                                      #language='en',
                                      sort_by='relevancy')
                                     # page=2)

# %%
national_post_resDf = pd.DataFrame()
national_post_resDf['source_name'] = [article['source']['name'] for article in national_post_res['articles']]
national_post_resDf['source_id'] = [article['source']['id'] for article in national_post_res['articles']]   
national_post_resDf['publish_date'] = [article['publishedAt'] for article in national_post_res['articles']]
national_post_resDf['title'] = [article['title'] for article in national_post_res['articles']]
national_post_resDf['text'] = [article['content'] for article in national_post_res['articles']]
national_post_resDf['url'] = [article['url'] for article in national_post_res['articles']]

# %%
ctvnews_res = newsapi.get_everything(q='climate',
                                      # sources='cbc-news' ,
                                     domains='ctvnews.ca',
                                      #from_param='2023-12-01',
                                      #to='2023-12-12',
                                      #language='en',
                                      sort_by='relevancy')
                                     # page=2)

# %%
ctvnews_resDf = pd.DataFrame()
ctvnews_resDf['source_name'] = [article['source']['name'] for article in ctvnews_res['articles']]
ctvnews_resDf['source_id'] = [article['source']['id'] for article in ctvnews_res['articles']]
ctvnews_resDf['publish_date'] = [article['publishedAt'] for article in ctvnews_res['articles']]
ctvnews_resDf['title'] = [article['title'] for article in ctvnews_res['articles']]
ctvnews_resDf['text'] = [article['content'] for article in ctvnews_res['articles']]
ctvnews_resDf['url'] = [article['url'] for article in ctvnews_res['articles']]

# %%
calgaryherald_res = newsapi.get_everything(q='climate',
                                        # sources='cbc-news' ,
                                         domains='calgaryherald.com',
                                        #from_param='2023-12-01',
                                        #to='2023-12-12',
                                        #language='en',
                                        sort_by='relevancy')
                                         # page=2)

# %%
calgaryherald_resDf = pd.DataFrame()
calgaryherald_resDf['source_name'] = [article['source']['name'] for article in calgaryherald_res['articles']]
calgaryherald_resDf['source_id'] = [article['source']['id'] for article in calgaryherald_res['articles']]
calgaryherald_resDf['publish_date'] = [article['publishedAt'] for article in calgaryherald_res['articles']]
calgaryherald_resDf['title'] = [article['title'] for article in calgaryherald_res['articles']]
calgaryherald_resDf['text'] = [article['content'] for article in calgaryherald_res['articles']]
calgaryherald_resDf['url'] = [article['url'] for article in calgaryherald_res['articles']]

# %%
globalnews_res = newsapi.get_everything(q='climate', 
                                        # sources='cbc-news' ,
                                        domains='globalnews.ca',
                                        #from_param='2023-12-01',
                                        #to='2023-12-12',
                                        #language='en',
                                        sort_by='relevancy')
                                        # page=2)

# %%
globalnews_resDf = pd.DataFrame()
globalnews_resDf['source_name'] = [article['source']['name'] for article in globalnews_res['articles']]
globalnews_resDf['source_id'] = [article['source']['id'] for article in globalnews_res['articles']]
globalnews_resDf['publish_date'] = [article['publishedAt'] for article in globalnews_res['articles']]
globalnews_resDf['title'] = [article['title'] for article in globalnews_res['articles']]
globalnews_resDf['text'] = [article['content'] for article in globalnews_res['articles']]
globalnews_resDf['url'] = [article['url'] for article in globalnews_res['articles']]

# %%
cbc_res = newsapi.get_everything(q='climate',
                                      sources='cbc-news' ,
                                     #domains='cbc.ca/news',
                                      #from_param='2023-12-01',
                                      #to='2023-12-12',
                                      #language='en',
                                      sort_by='relevancy')
                                     # page=2)

# %%
cbc_resDf = pd.DataFrame()
cbc_resDf['source_name'] = [article['source']['name'] for article in cbc_res['articles']]
cbc_resDf['source_id'] = [article['source']['id'] for article in cbc_res['articles']]
cbc_resDf['publish_date'] = [article['publishedAt'] for article in cbc_res['articles']]
cbc_resDf['title'] = [article['title'] for article in cbc_res['articles']]
cbc_resDf['text'] = [article['content'] for article in cbc_res['articles']]
cbc_resDf['url'] = [article['url'] for article in cbc_res['articles']]

# %%
globemail_res = newsapi.get_everything(q='climate',
                                        sources='the-globe-and-mail' ,
                                         #domains='cbc.ca/news',
                                        #from_param='2023-12-01',
                                        #to='2023-12-12',
                                        #language='en',
                                        sort_by='relevancy')
                                         # page=2)

# %%
globemail_resDf = pd.DataFrame()
globemail_resDf['source_name'] = [article['source']['name'] for article in globemail_res['articles']]
globemail_resDf['source_id'] = [article['source']['id'] for article in globemail_res['articles']]
globemail_resDf['publish_date'] = [article['publishedAt'] for article in globemail_res['articles']]
globemail_resDf['title'] = [article['title'] for article in globemail_res['articles']]
globemail_resDf['text'] = [article['content'] for article in globemail_res['articles']]
globemail_resDf['url'] = [article['url'] for article in globemail_res['articles']]

# %%
googlenews_res = newsapi.get_everything(q='climate',
                                        sources='google-news-ca' ,
                                         #domains='cbc.ca/news',
                                        #from_param='2023-12-01',
                                        #to='2023-12-12',
                                        #language='en',
                                        sort_by='relevancy')
                                         # page=2)

# %%
googlenews_resDf = pd.DataFrame()
googlenews_resDf['source_name'] = [article['source']['name'] for article in googlenews_res['articles']]
googlenews_resDf['source_id'] = [article['source']['id'] for article in googlenews_res['articles']]
googlenews_resDf['publish_date'] = [article['publishedAt'] for article in googlenews_res['articles']]
googlenews_resDf['title'] = [article['title'] for article in googlenews_res['articles']]
googlenews_resDf['text'] = [article['content'] for article in googlenews_res['articles']]
googlenews_resDf['url'] = [article['url'] for article in googlenews_res['articles']]

# %%
financialpost_res = newsapi.get_everything(q='climate',
                                        sources='financial-post' ,
                                         #domains='cbc.ca/news',
                                        #from_param='2023-12-01',
                                        #to='2023-12-12',
                                        #language='en',
                                        sort_by='relevancy')
                                         # page=2)

# %%
financialpost_resDf = pd.DataFrame()
financialpost_resDf['source_name'] = [article['source']['name'] for article in financialpost_res['articles']]
financialpost_resDf['source_id'] = [article['source']['id'] for article in financialpost_res['articles']]
financialpost_resDf['publish_date'] = [article['publishedAt'] for article in financialpost_res['articles']]
financialpost_resDf['title'] = [article['title'] for article in financialpost_res['articles']]
financialpost_resDf['text'] = [article['content'] for article in financialpost_res['articles']]
financialpost_resDf['url'] = [article['url'] for article in financialpost_res['articles']]

# %%
# concatenating all the dataframes from each source pull 
all_sources_resDf = pd.concat([cbc_resDf, globemail_resDf, googlenews_resDf, financialpost_resDf, cbc_resDf, globalnews_resDf, calgaryherald_resDf, ctvnews_resDf, national_post_resDf])

# %%
all_sources_resDf
# Out:
#        source_name source_id          publish_date  \
# 0         CBC News  cbc-news  2024-01-25T17:08:14Z
# 1         CBC News  cbc-news  2024-02-02T17:13:17Z
# 2         CBC News  cbc-news  2024-02-01T18:33:06Z
# 3         CBC News  cbc-news  2024-01-16T22:39:54Z
# 4         CBC News  cbc-news  2024-01-17T09:00:00Z
# ..             ...       ...                   ...
# 3      Global News      None  2024-02-02T16:14:43Z
# 0   Calgary Herald      None  2024-02-08T00:55:51Z
# 1   Calgary Herald      None  2024-01-26T13:50:50Z
# 0       Ctvnews.ca      None  2024-01-27T03:57:36Z
# 0    National Post      None  2024-01-16T23:03:29Z
#
#                                                 title  \
# 0   Are heat pumps a climate solution in Canada's ...
# 1   Greta Thunberg, 4 others acquitted on London c...
# 2   How effective a climate solution is removing C...
# 3   YouTube earns millions a year channels that pr...
# 4   Climate change threatens northern Ontario's wi...
# ...

# %%
all_sources_resDf_v2 = all_sources_resDf.to_csv('all_sources_resDf.csv')

# %%
# sources with source id
all_sources_climate_withid = newsapi.get_everything(q='climate',
                                      sources='cbc-news,the-globe-and-mail,google-news-ca,financial-post',
                                     #domains='cbc.ca/news',
                                      #from_param='2023-12-01',
                                      #to='2023-12-12',
                                      #language='en',
                                      sort_by='relevancy')
                                     # page=2)

# %%
# sources with domains
all_sources_climate_withdomain = newsapi.get_everything(q='climate',
                                      # sources='cbc-news' ,
                                     domains='nationalpost.com , ctvnews.ca,calgaryherald.com , calgaryherald.com, globalnews.ca',
                                      #from_param='2023-12-01',
                                      #to='2023-12-12',
                                      #language='en',
                                      sort_by='relevancy')
                                     # page=2)

# %%
all_sources_climate_withdomain
# Out:
# {'status': 'ok',
#  'totalResults': 8,
#  'articles': [{'source': {'id': None, 'name': 'Ctvnews.ca'},
#    'author': 'Ctv News',
#    'title': 'Amazon: MacKenzie Scott sold US$10B in shares last year',
#    'description': 'MacKenzie Scott unloaded nearly 65.3 million shares of Amazon, currently worth more than US$10 billion, in 2023, according to a filing.',
#    'url': 'https://www.ctvnews.ca/business/mackenzie-scott-sold-65-million-amazon-shares-worth-more-than-us-10b-in-the-last-year-1.6744762',
#    'urlToImage': 'https://www.ctvnews.ca/content/dam/ctvnews/en/images/2024/1/26/cnn-mackenzie-scott-1-6744763-1706325840549.jpg',
#    'publishedAt': '2024-01-27T03:57:36Z',
#    'content': 'MacKenzie Scott continues to sell billions of dollars in Amazon stock.\r\nIn 2023, she unloaded nearly 65.3 million shares of Amazon, currently worth more than US$10 billion, according to a filing.\r\nAf… [+1311 chars]'},
#   {'source': {'id': None, 'name': 'Global News'},
# ...

# %%
len(all_sources_climate_withdomain['articles'])
# Out:
# 8

# %%
len(all_sources_climate_withid['articles'])
# Out:
# 100

# %%
# i think it maxes out at 100 articles per query!!!
# even if there are more articles than that that it finds

# %%
all_sources_climate_withidDf = pd.DataFrame()

# %%
all_sources_climate_withidDf['source_name'] = [article['source']['name'] for article in all_sources_climate_withid['articles']]
all_sources_climate_withidDf['source_id'] = [article['source']['id'] for article in all_sources_climate_withid['articles']]
all_sources_climate_withidDf['publish_date'] = [article['publishedAt'] for article in all_sources_climate_withid['articles']]
all_sources_climate_withidDf['title'] = [article['title'] for article in all_sources_climate_withid['articles']]
all_sources_climate_withidDf['text'] = [article['content'] for article in all_sources_climate_withid['articles']]
all_sources_climate_withidDf['url'] = [article['url'] for article in all_sources_climate_withid['articles']]

# %%
all_sources_climate_withdomainDf = pd.DataFrame()

# %%
all_sources_climate_withdomainDf['source_name'] = [article['source']['name'] for article in all_sources_climate_withdomain['articles']]
all_sources_climate_withdomainDf['source_id'] = [article['source']['id'] for article in all_sources_climate_withdomain['articles']]
all_sources_climate_withdomainDf['publish_date'] = [article['publishedAt'] for article in all_sources_climate_withdomain['articles']]
all_sources_climate_withdomainDf['title'] = [article['title'] for article in all_sources_climate_withdomain['articles']]
all_sources_climate_withdomainDf['text'] = [article['content'] for article in all_sources_climate_withdomain['articles']]
all_sources_climate_withdomainDf['url'] = [article['url'] for article in all_sources_climate_withdomain['articles']]

# %%
all_sources_climate_withdomainDf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xz/kqr98cqj40l8xvbjfwrpj9q40000gn/T/ipykernel_22717/2580522294.py in <module>
# ----> 1 all_sources_climate_withdomainDf
#
# NameError: name 'all_sources_climate_withdomainDf' is not defined

# %%
all_sources_climateDf = pd.concat([all_sources_climate_withidDf, all_sources_climate_withdomainDf])

# %%
all_sources_climateDf
# Out:
#        source_name       source_id          publish_date  \
# 0   Financial Post  financial-post  2024-01-27T16:52:37Z
# 1         CBC News        cbc-news  2024-01-25T17:08:14Z
# 2         CBC News        cbc-news  2024-02-02T17:13:17Z
# 3         CBC News        cbc-news  2024-02-01T18:33:06Z
# 4         CBC News        cbc-news  2024-01-16T22:39:54Z
# ..             ...             ...                   ...
# 3    National Post            None  2024-01-16T23:03:29Z
# 4      Global News            None  2024-01-20T02:38:43Z
# 5    National Post            None  2024-01-09T11:07:42Z
# 6      Global News            None  2024-02-02T16:14:43Z
# 7   Calgary Herald            None  2024-01-26T13:50:50Z
#
#                                                 title  \
# 0   CHEVRON Says CA Climate Pollicies Risk Gas Sho...
# 1   Are heat pumps a climate solution in Canada's ...
# 2   Greta Thunberg, 4 others acquitted on London c...
# 3   How effective a climate solution is removing C...
# ...

# %%
# all_articles_source_1 = newsapi.get_everything(q='fire',
#                                       sources='the-globe-and-mail', 
#                                      # domains='cbc.ca/news',)
#                                       #from_param='2023-12-01',
#                                       #to='2023-12-12',
#                                       #language='en',
#                                       sort_by='relevancy')
#                                      # page=2)

# %%
# all_articles_source_1
# Out:
# {'status': 'ok',
#  'totalResults': 2,
#  'articles': [{'source': {'id': 'the-globe-and-mail',
#     'name': 'The Globe And Mail'},
#    'author': 'Matt Lundy',
#    'title': 'Canada stuck in ‘population trap,’ needs to reduce immigration, bank economists say',
#    'description': '‘Staggering’ growth is stretching country’s capacity, report says, with residential construction nowhere near enough to house newcomers',
#    'url': 'https://www.theglobeandmail.com/business/article-canada-stuck-in-population-trap-needs-to-reduce-immigration-bank/',
#    'urlToImage': 'https://www.theglobeandmail.com/resizer/v2/ZWFLVHDOVBMSVFJBLR67PF37FY.jpg?auth=4faf5e68d212ce86bce28c9aab7d0e0165ff3fc514315c728dbfbf9bfb346f8a&width=1200&height=800&quality=80',
#    'publishedAt': '2024-01-15T18:17:25Z',
# ...

# %%
# all_articles_source_2 = newsapi.get_everything(q='climate',
#                                       #sources='national-post-ca' ,
#                                       domains='nationalpost.com',
#                                       #from_param='2023-12-01',
#                                       #to='2023-12-12',
#                                       #language='en',
#                                       sort_by='relevancy')
#                                      # page=2)

# %%
# all_articles_source_2
# Out:
# {'status': 'ok',
#  'totalResults': 2,
#  'articles': [{'source': {'id': None, 'name': 'National Post'},
#    'author': 'Tyler Dawson',
#    'title': 'Jordan Peterson loses fight to avoid mandatory social media training',
#    'description': "An Ontario court has dismissed Jordan Peterson's appeal of an earlier decision that sided with the College of Psychologists of Ontario",
#    'url': 'https://nationalpost.com/news/canada/exclusive-jordan-peterson-loses-fight-with-psychology-college-over-mandatory-social-media-training',
#    'urlToImage': 'https://smartcdn.gprod.postmedia.digital/nationalpost/wp-content/uploads/2024/01/jordan-peterson-college-psychologists-socail-media.jpg',
#    'publishedAt': '2024-01-16T23:03:29Z',
#    'content': 'Jordan Peterson has failed in his attempt to have the Ontario court system prevent the College of Psychologists of Ontario from ordering him to undergo remedial social media training.\r\nOn Tuesday, a … [+4356 chars]'},
# ...

# %%
# all_articles_source_2 = newsapi.get_everything(#q='climate',
#                                       #sources='montreal-gazette' ,
#                                       domains='ctvnews.ca',
#                                       #from_param='2023-12-01',
#                                       #to='2023-12-12',
#                                       #language='en',
#                                       sort_by='relevancy')
#                                      # page=2)

# %%
# all_articles_source_2
# Out:
# {'status': 'ok',
#  'totalResults': 34,
#  'articles': [{'source': {'id': None, 'name': 'Ctvnews.ca'},
#    'author': 'Ctv News',
#    'title': 'Adan Canto dead at 42',
#    'description': 'Adan Canto, the Mexican singer and actor best known for his roles in "X-Men: Days of Future Past" and "Agent Game" as well as the TV series "The Cleaning Lady," has died. He was 42.',
#    'url': 'https://www.ctvnews.ca/entertainment/adan-canto-known-for-his-versatility-in-roles-in-x-men-and-designated-survivor-dies-at-42-1.6718938',
#    'urlToImage': 'https://www.ctvnews.ca/content/dam/ctvnews/en/images/2024/1/9/actor-adan-canto-attends-1-6718939-1704857771142.jpg',
#    'publishedAt': '2024-01-10T03:42:00Z',
#    'content': 'LOS ANGELES - \r\nAdan Canto, the Mexican singer and actor best known for his roles in "X-Men: Days of Future Past" and "Agent Game" as well as the TV series "The Cleaning Lady," has died. He was 42.\r\n… [+2259 chars]'},
#   {'source': {'id': None, 'name': 'Ctvnews.ca'},
# ...

# %%
# all_articles_source_3 = newsapi.get_everything(#q='fire',
#                                       sources='google-news-ca' ,
#                                     #domains='',
#                                       #from_param='2023-12-01',
#                                       #to='2023-12-12',
#                                       #language='en',
#                                       sort_by='relevancy')
#                                      # page=2)

# %%
# all_articles_source_3
# Out:
# {'status': 'ok',
#  'totalResults': 70,
#  'articles': [{'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': 'Amit Zavery',
#    'title': 'Removing data transfer fees when moving off Google Cloud',
#    'description': 'Customers discontinuing their use of Google Cloud can move their data without incurring any network data transfer fees.',
#    'url': 'https://cloud.google.com/blog/products/networking/eliminating-data-transfer-fees-when-migrating-off-google-cloud',
#    'urlToImage': 'https://storage.googleapis.com/gweb-cloudblog-publish/images/DO_NOT_USE_.max-2500x2500.jpg',
#    'publishedAt': '2024-01-11T15:49:27Z',
#    'content': 'At Google Cloud, we work to support a thriving cloud ecosystem that is open, secure, and interoperable. When customers business needs evolve, the cloud should be flexible enough to accommodate those … [+2277 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
# ...

# %%
# all_articles_source_4 = newsapi.get_everything(#q='climate',
#                                       sources='financial-post' ,
#                                     #domains='',
#                                       #from_param='2023-12-01',
#                                       #to='2023-12-12',
#                                       #language='en',
#                                       sort_by='relevancy')
#                                      # page=2)

# %%
# all_articles_source_4
# Out:
# {'status': 'ok',
#  'totalResults': 273,
#  'articles': [{'source': {'id': 'financial-post', 'name': 'Financial Post'},
#    'author': 'Bloomberg News',
#    'title': 'CHEVRON Says CA Climate Pollicies Risk Gas Shortages...',
#    'description': 'Chevron Corp. warns its home state of California’s climate policies are a “dangerous game” that risk causing gasoline price spikes and shortages.',
#    'url': 'https://financialpost.com/pmn/business-pmn/chevron-says-california-plays-a-risky-game-with-climate-and-gasoline',
#    'urlToImage': 'https://smartcdn.gprod.postmedia.digital/financialpost/wp-content/uploads/2024/01/775799343.jpg',
#    'publishedAt': '2024-01-27T16:52:37Z',
#    'content': "Chevron Corp. warns its home state of Californias climate policies are a dangerous game that risk causing gasoline price spikes and shortages.\r\nAuthor of the article:\r\nChevron's refinery in Richmond,… [+7882 chars]"},
#   {'source': {'id': 'financial-post', 'name': 'Financial Post'},
# ...

# %%
# all_articles_source_5 = newsapi.get_everything(#q='climate',
#                                       # sources='' ,
#                                     domains='calgaryherald.com',
#                                       #from_param='2023-12-01',
#                                       #to='2023-12-12',
#                                       #language='en',
#                                       sort_by='relevancy')
#                                      # page=2)

# %%
# all_articles_source_5
# Out:
# {'status': 'ok',
#  'totalResults': 4,
#  'articles': [{'source': {'id': None, 'name': 'Calgary Herald'},
#    'author': 'Rick Bell',
#    'title': 'Bell: Danielle Smith slams Calgary bag bylaw, calls out city council',
#    'description': "Premier Danielle Smith knocks Calgary bag bylaw, the single-use items law, tells critics to call city hall as she looks at bylaw's legality",
#    'url': 'https://calgaryherald.com/opinion/columnists/bell-danielle-smith-calgary-bag-bylaw-city-council',
#    'urlToImage': 'https://smartcdn.gprod.postmedia.digital/calgaryherald/wp-content/uploads/2024/01/Healthcare-PremierPresser015-copy.jpg',
#    'publishedAt': '2024-01-26T12:14:38Z',
#    'content': "'I think theres a little bit of ideology getting ahead of common sense here,' said Smith\r\nPremier Danielle Smith at the McDougall Centre in Calgary on Thursday, December 21, 2023.Darren Makowichuk/Po… [+7249 chars]"},
#   {'source': {'id': None, 'name': 'Calgary Herald'},
# ...

# %%
# all_articles_source_6 = newsapi.get_everything(#q='climate',
#                                       #sources='torontosun' ,
#                                     domains='torontosun.com',
#                                       #from_param='2023-12-01',
#                                       #to='2023-12-12',
#                                       #language='en',
#                                       sort_by='relevancy')
#                                      # page=2)

# %%
# all_articles_source_6
# Out:
# {'status': 'ok',
#  'totalResults': 4,
#  'articles': [{'source': {'id': None, 'name': 'Toronto Sun'},
#    'author': 'Mark Daniell',
#    'title': 'Joe Rogan urges Canada to vote for Pierre Poilievre',
#    'description': "Joe Rogan is letting Canadians know there's only one choice in the next federal election — Pierre Poilievre.",
#    'url': 'https://torontosun.com/entertainment/celebrity/joe-rogan-urges-canada-to-vote-for-pierre-poilievre-get-your-s-together',
#    'urlToImage': 'https://smartcdn.gprod.postmedia.digital/torontosun/wp-content/uploads/2024/01/joe_rogan_f_trudeau-e1705944258673.jpg',
#    'publishedAt': '2024-01-26T14:44:19Z',
#    'content': "'Come back. Come back to what you used to be,' popular podcaster says as he endorses Conservative leader\r\n Get the latest from Mark Daniell straight to your inbox Sign Up\r\nJoe Rogan on 'The Joe Rogan… [+9143 chars]"},
#   {'source': {'id': None, 'name': 'Toronto Sun'},
#    'author': 'Brian Lilley',
# ...

# %%
# all_articles_source_7 = newsapi.get_everything(#q='climate',
#                                       #sources='globalnews' ,
#                                     domains='globalnews.ca',
#                                       #from_param='2023-12-01',
#                                       #to='2023-12-12',
#                                       #language='en',
#                                       sort_by='relevancy')
#                                      # page=2)

# %%
# all_articles_source_7
# Out:
# {'status': 'ok',
#  'totalResults': 66,
#  'articles': [{'source': {'id': None, 'name': 'Global News'},
#    'author': 'Simon Little',
#    'title': "AI 'hallucinated' fake legal cases filed to B.C. court in Canadian first",
#    'description': 'Lawyers Lorne and Fraser MacLean told Global News they discovered fake case law submitted by the opposing lawyer in a civil case in B.C. Supreme Court.',
#    'url': 'https://globalnews.ca/news/10238699/fake-legal-case-bc-ai/',
#    'urlToImage': 'https://globalnews.ca/wp-content/uploads/2023/12/20231212161240-6578d4198ca73bcf6f2e1b7bjpeg.jpg?quality=85&strip=all&w=720&h=379&crop=1',
#    'publishedAt': '2024-01-24T08:51:33Z',
#    'content': 'A B.C. courtroom is believed to be the site of Canada’s first case of artificial intelligence inventing fake legal cases.\r\nLawyers Lorne and Fraser MacLean told Global News they discovered fake case … [+4232 chars]'},
#   {'source': {'id': None, 'name': 'Global News'},
# ...

# %%
# /v2/top-headlines/sources
#sources = newsapi.get_sources()
